# %% [markdown]
# # huggingface에서 CTspine1k 데이터셋 다운로드
#  - 경로 : \졸업작품\dataset

# %%
from huggingface_hub import snapshot_download

local_dir = snapshot_download(
    repo_id="alexanderdann/CTSpine1K",
    repo_type="dataset",
    local_dir="./CTSpine1K"
)

print(local_dir)
